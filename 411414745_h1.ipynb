# %% [markdown]
# <a href="https://colab.research.google.com/github/ryan09200000/115-1/blob/main/411414745_h1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#本金
a=50000
#年利率
b=0.015
#年
n=5
x=a*(1+b)**n
print(x)
# Out:
# 53864.20019421873
