# %% [markdown]
# <a href="https://colab.research.google.com/github/ryan09200000/115-1/blob/main/411414745_h2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=int(input("請輸入目前金幣數量:"))
print(x)
y=int(input("請輸入獲得金幣數量:"))
print(y)
z=x+y
print(f"任務完成！你現在有{z}枚金幣")
# Out:
# 請輸入目前金幣數量:500
# 500
# 請輸入獲得金幣數量:250
# 250
# 任務完成！你現在有750枚金幣
